# %%
from skimage.restoration import denoise_bilateral,denoise_tv_chambolle
import skimage
import matplotlib.pyplot as plt



photos=plt.imread('Image1.jpg')

denoise=denoise_tv_chambolle(photos,multichannel=True)



plt.imshow(denoise)
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_7164\1067004646.py:9: FutureWarning: `multichannel` is a deprecated argument name for `denoise_tv_chambolle`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   denoise=denoise_tv_chambolle(photos,multichannel=True)
